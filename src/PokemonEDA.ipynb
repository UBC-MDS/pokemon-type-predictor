# %% [markdown]
# # Pokemon type predictor - Exploratory data analysis
#
# ### Group information:
# ##### Team number: 8
# ##### Team members: Sarah Abdelazim, Wilfred Hass, Vincent Ho, Caroline Tang
# ##### Source : https://gist.github.com/HansAnonymous/56d3c1f8136f7e0385cc781cf18d486c
#
# # Introduction
# This dataset contains different attributes of 1049 pokemon, such as their height, weight color, types, base stats, and abilities. Using this data, we want to predict a pokemon’s primary type based on its other characteristics.

# %%
import pandas as pd
import altair as alt
from sklearn.model_selection import train_test_split

alt.renderers.enable('default')

# %% [markdown]
# #

# %% [markdown]
# ## 1.  Overview and Summary of the dataset

# %%
pokemon_df = pd.read_csv("../data/raw/pokemon.csv")

# %%
pd.set_option('display.max_columns', None)

pokemon_df.head()
# Out:
#    NUMBER  CODE  SERIAL           NAME  TYPE1   TYPE2  COLOR   ABILITY1  \
# 0       1     1      11      Bulbasaur  Grass  Poison  Green   Overgrow
# 1       2     1      21        Ivysaur  Grass  Poison  Green   Overgrow
# 2       3     1      31       Venusaur  Grass  Poison  Green   Overgrow
# 3       3     2      32  Mega Venusaur  Grass  Poison  Green  Thick Fat
# 4       4     1      41     Charmander   Fire     NaN    Red      Blaze
#
#   ABILITY2 ABILITY HIDDEN  GENERATION  LEGENDARY  MEGA_EVOLUTION  HEIGHT  \
# 0      NaN    Chrolophyll           1          0               0     0.7
# 1      NaN    Chrolophyll           1          0               0     1.0
# 2      NaN    Chrolophyll           1          0               0     2.0
# 3      NaN            NaN           1          0               1     2.4
# 4      NaN    Solar Power           1          0               0     0.6
#
#    WEIGHT  HP  ATK  DEF  SP_ATK  SP_DEF  SPD  TOTAL
# 0     6.9  45   49   49      65      65   45    318
# 1    13.0  60   62   63      80      80   60    405
# 2   100.0  80   82   83     100     100   80    525
# 3   155.5  80  100  123     122     120   80    625
# 4     8.5  39   52   43      60      50   65    309

# %%
pokemon_df.describe()
# Out:
#             NUMBER         CODE       SERIAL   GENERATION    LEGENDARY  \
# count  1048.000000  1048.000000  1048.000000  1048.000000  1048.000000
# mean    442.412214     1.187977  4425.310115     4.260496     0.118321
# std     260.578582     0.528074  2605.778646     2.268484     0.323142
# min       1.000000     1.000000    11.000000     1.000000     0.000000
# 25%     217.750000     1.000000  2178.500000     2.000000     0.000000
# 50%     438.500000     1.000000  4386.000000     4.000000     0.000000
# 75%     667.250000     1.000000  6673.500000     6.000000     0.000000
# max     898.000000     6.000000  8983.000000     8.000000     1.000000
#
#        MEGA_EVOLUTION       HEIGHT       WEIGHT           HP          ATK  \
# count     1048.000000  1048.000000  1048.000000  1048.000000  1048.000000
# mean         0.047710     1.257252    71.057634    69.842557    80.250000
# std          0.213254     1.256724   132.054353    26.037975    32.466227
# min          0.000000     0.100000     0.100000     1.000000     5.000000
# 25%          0.000000     0.600000     9.000000    50.000000    55.000000
# 50%          0.000000     1.000000    29.000000    68.000000    76.500000
# 75%          0.000000     1.500000    70.625000    80.000000   100.000000
# max          1.000000    14.500000   999.900000   255.000000   190.000000
#
#                DEF       SP_ATK       SP_DEF          SPD        TOTAL
# count  1048.000000  1048.000000  1048.000000  1048.000000  1048.000000
# mean     74.340649    72.668893    71.885496    68.613550   437.601145
# std      30.738994    32.707936    27.458648    30.100794   120.150889
# min       5.000000    10.000000    20.000000     5.000000   175.000000
# 25%      50.000000    50.000000    50.000000    45.000000   330.000000
# 50%      70.000000    65.000000    70.000000    65.000000   455.000000
# 75%      90.000000    95.000000    90.000000    90.000000   515.000000
# max     230.000000   194.000000   230.000000   200.000000   780.000000

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NUMBER          1048 non-null   int64
#  1   CODE            1048 non-null   int64
#  2   SERIAL          1048 non-null   int64
#  3   NAME            1048 non-null   object
#  4   TYPE1           1048 non-null   object
#  5   TYPE2           554 non-null    object
#  6   COLOR           1048 non-null   object
#  7   ABILITY1        1048 non-null   object
#  8   ABILITY2        522 non-null    object
#  9   ABILITY HIDDEN  818 non-null    object
#  10  GENERATION      1048 non-null   int64
#  11  LEGENDARY       1048 non-null   int64
#  12  MEGA_EVOLUTION  1048 non-null   int64
#  13  HEIGHT          1048 non-null   float64
#  14  WEIGHT          1048 non-null   float64
#  15  HP              1048 non-null   int64
#  16  ATK             1048 non-null   int64
#  17  DEF             1048 non-null   int64
#  18  SP_ATK          1048 non-null   int64
#  19  SP_DEF          1048 non-null   int64
#  20  SPD             1048 non-null   int64
#  21  TOTAL           1048 non-null   int64
# dtypes: float64(2), int64(13), object(7)
# memory usage: 180.2+ KB

# %% [markdown]
# There are some missing values since not all pokemon have a second type, second ability or hidden abilities.

# %% [markdown]
# #

# %% [markdown]
# ## 2. Partition the data set into training and test sets

# %% [markdown]
# Before proceeding to EDA section, we will split the data such that 70% of observations are in training and 30% of observations are in the test set.

# %%
train_df, test_df = train_test_split(pokemon_df, test_size=0.3, random_state=123)

# %% [markdown]
# #

# %% [markdown]
# ## 3. Exploratory analysis on the training data set

# %% [markdown]
# #

# %% [markdown]
# #### a. Distributions of numerical columns

# %%
alt.Chart(train_df).mark_bar().encode(
     alt.X(alt.repeat(), type='quantitative', bin=alt.Bin(maxbins=40)),
     y='count()',
).properties(
    width=300,
    height=200
).repeat(
    ['NUMBER','CODE','GENERATION','LEGENDARY','MEGA_EVOLUTION', 'HEIGHT', 'WEIGHT','HP','ATK','DEF','SP_ATK','SP_DEF','SPD','TOTAL'], columns=3
)
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# Figure 1. Distributions of numeric characteristics.
#
# Most of the numerical attributes appear to be relatively normally distributed except for HEIGHT and WEIGHT, which are right skewed. Only a small amount of pokemon can evolve, be lengendary or have a mega evolution form so it makes sense that CODE, LEGENDARY and MEGA_EVOLUTION are so imbalanced.

# %% [markdown]
# #

# %% [markdown]
# #### b. Distributions of categorical columns

# %%
alt.Chart(train_df).mark_bar().encode(
     x='count()',
     y=alt.X(alt.repeat()),
).properties(
    width=300,
    height=1500
).repeat(
    ['TYPE1','TYPE2','COLOR', 'ABILITY1','ABILITY2','ABILITY HIDDEN' ],
    columns=3
)
# Out:
# alt.RepeatChart(...)

# %% [markdown]
# Figure 2. Distributions of categorical characteristics.
#
# For the categorical columns, we can see that the types of pokemons are not quite balanced and that some pokemon share the same ability.

# %% [markdown]
# #

# %% [markdown]
# #### c. Correlation table for numerical columns

# %%
train_df.corr("spearman").style.background_gradient()
# Out:
# <style type="text/css">
# #T_842a6_row0_col0, #T_842a6_row0_col2, #T_842a6_row1_col1, #T_842a6_row2_col0, #T_842a6_row2_col2, #T_842a6_row3_col3, #T_842a6_row4_col4, #T_842a6_row5_col5, #T_842a6_row6_col6, #T_842a6_row7_col7, #T_842a6_row8_col8, #T_842a6_row9_col9, #T_842a6_row10_col10, #T_842a6_row11_col11, #T_842a6_row12_col12, #T_842a6_row13_col13, #T_842a6_row14_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_842a6_row0_col1, #T_842a6_row1_col8, #T_842a6_row2_col1, #T_842a6_row3_col5, #T_842a6_row3_col6, #T_842a6_row3_col7, #T_842a6_row3_col9, #T_842a6_row3_col11, #T_842a6_row3_col12, #T_842a6_row3_col13, #T_842a6_row3_col14, #T_842a6_row5_col0, #T_842a6_row5_col2, #T_842a6_row5_col3, #T_842a6_row5_col4, #T_842a6_row13_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_842a6_row0_col3, #T_842a6_row2_col3 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_842a6_row0_col4, #T_842a6_row2_col4, #T_842a6_row5_col6, #T_842a6_row5_col14 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_842a6_row0_col5, #T_842a6_row2_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_842a6_row0_col6, #T_842a6_row2_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_842a6_row0_col7, #T_842a6_row2_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_842a6_row0_col8, #T_842a6_row2_col8 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_842a6_row0_col9, #T_842a6_row2_col9, #T_842a6_row5_col8 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_842a6_row0_col10, #T_842a6_row2_col10 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_842a6_row0_col11, #T_842a6_row2_col11 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_842a6_row0_col12, #T_842a6_row2_col12 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_842a6_row0_col13, #T_842a6_row2_col13, #T_842a6_row10_col13 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_842a6_row0_col14, #T_842a6_row1_col4, #T_842a6_row2_col14 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_842a6_row1_col0, #T_842a6_row1_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_842a6_row1_col3, #T_842a6_row7_col4, #T_842a6_row8_col13, #T_842a6_row11_col0, #T_842a6_row11_col2, #T_842a6_row11_col9, #T_842a6_row12_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_842a6_row1_col5, #T_842a6_row10_col14 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_842a6_row1_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_842a6_row1_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_842a6_row1_col9, #T_842a6_row1_col11 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T
{
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_842a6_row10_col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_842a6_row10_col5 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_842a6_row10_col6, #T_842a6_row12_col6 {
#   background-color: #75a9cf;
#   col

# %% [markdown]
# In the correlation table, we can see that the numeric attributes have a high correlation with each other, which makes sense because if the pokemon is stronger, its overall score should be higher. However, their numerical attributes are not highly correlated with some identification variables such as NUMBER, CODE, SERIAL and GENERATION. We might consider dropping these columns since they are generally unique to each pokemon.

# %% [markdown]
# #

# %% [markdown]
# #### d. Explore some interesting relationships between categorical variables

# %%
# Primany Ability of pokemon vs Primany Type of pokemon

alt.Chart(train_df).mark_square().encode(
    x='ABILITY1',
    y='TYPE1',
    color='count()',
    size='count()')
# Out:
# alt.Chart(...)

# %% [markdown]
# Figure 3. Correlation plot between primary type and primary ability
#
# It seems like most of the pokemon's types have their own ability or only share with a few of other types.

# %% [markdown]
# #

# %%
# TYPE of pokemon vs COLOR of pokemon

alt.Chart(train_df).mark_square().encode(
    x='TYPE1',
    y='COLOR',
    color='count()',
    size='count()')
# Out:
# alt.Chart(...)

# %% [markdown]
# Figure 4. Correlation plot between primary type and main color
#
# We can see that many pokemon types actually have pokemon in all ten colors while some types have one dominant color. For example, Water types are mostly blue and Grass types are mostly Green.

# %%
#Preprocessing session for later milestones

imputed_train_df_df = train_df.copy()

imputed_train_df_df['TYPE2'].fillna("No Other Type", inplace=True)
imputed_train_df_df['ABILITY2'].fillna("No Other Ability", inplace=True)
imputed_train_df_df['ABILITY HIDDEN'].fillna("No Ability Hidden", inplace=True)

# %%
imputed_train_df_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 733 entries, 787 to 1041
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NUMBER          733 non-null    int64
#  1   CODE            733 non-null    int64
#  2   SERIAL          733 non-null    int64
#  3   NAME            733 non-null    object
#  4   TYPE1           733 non-null    object
#  5   TYPE2           733 non-null    object
#  6   COLOR           733 non-null    object
#  7   ABILITY1        733 non-null    object
#  8   ABILITY2        733 non-null    object
#  9   ABILITY HIDDEN  733 non-null    object
#  10  GENERATION      733 non-null    int64
#  11  LEGENDARY       733 non-null    int64
#  12  MEGA_EVOLUTION  733 non-null    int64
#  13  HEIGHT          733 non-null    float64
#  14  WEIGHT          733 non-null    float64
#  15  HP              733 non-null    int64
#  16  ATK             733 non-null    int64
#  17  DEF             733 non-null    int64
#  18  SP_ATK          733 non-null    int64
#  19  SP_DEF          733 non-null    int64
#  20  SPD             733 non-null    int64
#  21  TOTAL           733 non-null    int64
# dtypes: float64(2), int64(13), object(7)
# memory usage: 131.7+ KB

# %%
binary_features = ['LEGENDARY','MEGA_EVOLUTION']
categorical_features = ['TYPE1','TYPE2','COLOR', 'ABILITY1','ABILITY2','ABILITY HIDDEN']
numeric_features = ['HEIGHT', 'WEIGHT','HP','ATK','DEF','SP_ATK','SP_DEF','SPD']
drop_features = ['NUMBER','CODE','GENERATION', 'TOTAL' ]
